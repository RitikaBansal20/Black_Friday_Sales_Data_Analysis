# %%
import pandas as pd
df=pd.read_csv("BlackFriday.csv")
del df['Product_Category_2']
del df['Product_Category_3']
df
# Out:
#        User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0      1000001  P00069042      F   0-17          10             A
# 1      1000001  P00248942      F   0-17          10             A
# 2      1000001  P00087842      F   0-17          10             A
# 3      1000001  P00085442      F   0-17          10             A
# 4      1000002  P00285442      M    55+          16             C
# ...        ...        ...    ...    ...         ...           ...
# 19276  1003032  P00158942      M  26-35           0             A
# 19277  1003032  P00187442      M  26-35           0             A
# 19278  1003032  P00057542      M  26-35           0             A
# 19279  1003032  P00186842      M  26-35           0             A
# 19280  1003032   P0094942      M  26-35           0             A
#
#       Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                              2               0                 3.0    8370.0
# 1                              2               0                 1.0   15200.0
# 2                              2               0                12.0    1422.0
# 3                              2               0                12.0    1057.0
# 4                             4+               0                 8.0    7969.0
# ...                          ...             ...                 ...       ...
# 19276                          1               1                 1.0   15741.0
# 19277                          1               1                 2.0   12861.0
# 19278                          1               1                 3.0   13565.0
# 19279                          1               1                 3.0   13520.0
# 19280                          1               1                 NaN       NaN
#
# [19281 rows x 10 columns]

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      638
# 18-25    3948
# 26-35    7149
# 36-45    3912
# 46-50    1466
# 51-55    1386
# 55+       782
# dtype: int64

# %%
df.groupby('Age').size().plot(kind='bar'
                                 ,figsize =(12,6)
                                 ,title='Purchase Distribution by Age')
# Out:
# <AxesSubplot:title={'center':'Purchase Distribution by Age'}, xlabel='Age'>

# %%
df[df['Age']== '0-17']
# Out:
#        User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0      1000001  P00069042      F  0-17          10             A
# 1      1000001  P00248942      F  0-17          10             A
# 2      1000001  P00087842      F  0-17          10             A
# 3      1000001  P00085442      F  0-17          10             A
# 85     1000019  P00112542      M  0-17          10             A
# ...        ...        ...    ...   ...         ...           ...
# 19210  1003028  P00363242      M  0-17          10             C
# 19211  1003028  P00368142      M  0-17          10             C
# 19212  1003028  P00125942      M  0-17          10             C
# 19213  1003028  P00169742      M  0-17          10             C
# 19214  1003028  P00258742      M  0-17          10             C
#
#       Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                              2               0                 3.0    8370.0
# 1                              2               0                 1.0   15200.0
# 2                              2               0                12.0    1422.0
# 3                              2               0                12.0    1057.0
# 85                             3               0                 1.0    7746.0
# ...                          ...             ...                 ...       ...
# 19210                          3               0                 1.0   11758.0
# 19211                          3               0                 2.0   12857.0
# 19212                          3               0                 1.0   15376.0
# 19213                          3               0                 1.0   12089.0
# 19214                          3               0                 5.0    7112.0
#
# [638 rows x 10 columns]

# %%
len(df[df['Age']== '0-17'])
# Out:
# 638

# %%
for i in df['Age'].unique():
          print(i, " : ",df[df['Age']== i]['Product_ID'].nunique())
# Out:
# 0-17  :  470
# 55+  :  573
# 26-35  :  2003
# 46-50  :  945
# 51-55  :  869
# 36-45  :  1589
# 18-25  :  1514

# %%
lst=[]
for i in df['Age'].unique():
          lst.append([i,df[df['Age']== i]['Product_ID'].nunique()])
        
data=pd.DataFrame(lst, columns=['Age',"products"])
data
# Out:
#      Age  products
# 0   0-17       470
# 1    55+       573
# 2  26-35      2003
# 3  46-50       945
# 4  51-55       869
# 5  36-45      1589
# 6  18-25      1514

# %%
data.plot.bar(x='Age', figsize=(8,6))
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
df.groupby('Age').sum()['Purchase'].plot(kind='bar'
                                 ,figsize =(12,6)
                                 ,title='Amount Spend by Age')
# Out:
# <AxesSubplot:title={'center':'Amount Spend by Age'}, xlabel='Age'>

# %%
df.groupby('Age').mean()['Purchase'].plot(kind='pie'
                                 ,figsize =(12,6)
                                 ,autopct = "%.1f")
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
df.groupby('Marital_Status').size().plot(kind='pie'
                                 ,figsize =(12,6)
                                 ,autopct = "%.1f")
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.groupby('Gender').size().plot(kind='pie'
                                 ,figsize =(12,6)
                                 ,autopct = "%.1f")
# Out:
# <AxesSubplot:ylabel='None'>
